# %%
from bs4 import BeautifulSoup
import requests
import re
import requests
import pandas as pd

def search_company_page(company):
    company_page = ""
    #Given a company, find its webpage URL through the research system of Reuter

    #This URL return the search page for the given company
    search_url = f'https://www.reuters.com/search/news?sortBy=&dateRange=&blob={company}'

    #Creating url request and bs4 object
    req=requests.get(search_url)

    soup = BeautifulSoup(req.content, "html.parser")
    company_page = soup.find("div",class_="search-stock-ticker").findNext()["href"]

    #we return the final url of the webpage of the company
    return re.sub(r'overview','financial-highlights',"https://www.reuters.com"+company_page)

def get_data(company):
    url=search_company_page(company)
    req=requests.get(url)
    soup = BeautifulSoup(req.content, "html.parser")

    ##Get stock price from company page
    try:
        price_L=(soup.
               find("div",class_="sectionQuote nasdaqChange").
               findAll("span"))
        
        price = float(price_L[1].text.strip())
        currency=price_L[2].text.strip()
        
        
    except:
        price = "?"
        currency= "?"

    ##Get %change from company page
    try:
        change = float(re.sub(r'^[(]|[%)]+$',"",
                          soup.
                          find("div",class_="sectionQuote priceChange").
                          findAll("span")[4].
                          contents[0].
                          strip()))/100
        if change == "--":
            change = 0
            
    except:
        change = 0
        
        
    try:
    ##Get Shares owned by institutionnal holders
        shared_owned, =(float(re.sub(r'^[(]|[%)]+$',"",elmt.parent.parent.find(class_="data").contents[0]))
                        for elmt in soup.findAll("strong") 
                        if "Shares Owned" in elmt.contents[0])
    except:
        shared_owned = ""

    
    ##Get divident yield for company/industry/sector
    try:
        yield_list, *rest = (elmt.parent.findAll(class_="data")
                                   for elmt in soup.findAll("td") 
                                   if "Dividend Yield" in elmt.get_text())
    except:
        pass
    
    try:
        company_divident_yield = float(yield_list[0].text)
    except:
        company_divident_yield = "?"
        
    try:    
        industry_divident_yield = float(yield_list[1].text)
    except:
        industry_divident_yield = "?"

    try:    
        sector_divident_yield = float(yield_list[2].text)
    except:
        sector_divident_yield = "?"
    
    try:
        sell_year_ending_list, *rest = (elmt.parent.findAll(class_="data")
                                       for elmt in soup.findAll("td") 
                                       if "Quarter Ending" in elmt.get_text())
        try:
            sell_year_ending_nr = int(sell_year_ending_list[0].text)
        except:
            sell_year_ending_nr = "?"

        try:
            sell_year_ending_mean = float(re.sub(r"[,]","",(sell_year_ending_list[1].text)))
        except:
            sell_year_ending_mean = "?"

        try:
            sell_year_ending_high = float(re.sub(r"[,]","",(sell_year_ending_list[2].text)))
        except:
            sell_year_ending_high = "?"

        try:
            sell_year_ending_low = float(re.sub(r"[,]","",(sell_year_ending_list[3].text)))
        except:
            sell_year_ending_low = "?"

    except:
        sell_year_ending_nr = "?"
        sell_year_ending_mean = "?"
        sell_year_ending_high = "?"
        sell_year_ending_low = "?"   
        
        
    try:
        market = soup.find("span",class_="nasdaqChangeHeader").text.split("on ")[1]
    except:
            marker = "?"
    


    return {"Company":company.upper(),
            "Marker":market,
            "Date":pd.Timestamp.today(tz="UTC").date(),
            "Price":price,
            "Currency":currency,
            "Change":change,
            "Shared_owned":shared_owned,
            "Company_divident_yield":company_divident_yield,
            "Industry_divident_yield":industry_divident_yield,
            "Sell_year_ending_nr":sell_year_ending_nr,
            "Sell_year_ending_mean":sell_year_ending_mean,
            "Sell_year_ending_high":sell_year_ending_high,
            "Sell_year_ending_low":sell_year_ending_low}

# %%
urlCAC = "https://www.boursier.com/indices/composition/cac-40-FR0003500008,FR.html?tri=dcapi"
reqCAC=requests.get(urlCAC)
soupCAC = BeautifulSoup(reqCAC.content, "html.parser")
CAC40 = [elmt["title"] if "(" not in elmt["title"] else elmt["title"].split("(")[0] for elmt in soupCAC.findAll("a", class_="name--wrapper")]

# %%
reuter_L = []
company_list = ["Airbus","Danone","LVMH","total","edf","michelin","carrefour",'valeo','renault','peugeot','technipfmc']
for company in CAC40:
    try:
        reuter_L.append(get_data(re.sub(r" GROUP","",company)))
    except:
        print("Fail "+company)

reuter_df = pd.DataFrame(reuter_L,columns=reuter_L[0].keys())
# Out:
# Fail PSA GROUPE
# Fail ACCORHOTELS

# %%
reuter_df.sort_values("Change",ascending=False)
# Out:
#                  Company                                Marker        Date  \
# 34              PUBLICIS                  Paris Stock Exchange  2018-10-11
# 14                ORANGE                  Paris Stock Exchange  2018-10-11
# 2                L'OREAL                  Paris Stock Exchange  2018-10-11
# 30    STMICROELECTRONICS                  Berne Stock Exchange  2018-10-11
# 5            BNP PARIBAS                  Paris Stock Exchange  2018-10-11
# 6                    AXA                   Oslo Stock Exchange  2018-10-11
# 27             CAPGEMINI                  Paris Stock Exchange  2018-10-11
# 26              MICHELIN                  Paris Stock Exchange  2018-10-11
# 23           UNIBAIL-WFD              Amsterdam Stock Exchange  2018-10-11
# 22         ARCELORMITTAL              Amsterdam Stock Exchange  2018-10-11
# 1                   LVMH                  Milan Stock Exchange  2018-10-11
# 18     DASSAULT SYSTEMES                  Paris Stock Exchange  2018-10-11
# 36  VEOLIA ENVIRONNEMENT                  Paris Stock Exchange  2018-10-11
# 3                 SANOFI      National Stock Exchange of India  2018-10-11
# 17         PERNOD RICARD                  Paris Stock Exchange  2018-10-11
# 21               VIVENDI                  Paris Stock Exchange  2018-10-11
# 31                SODEXO                  Paris Stock Exchange  2018-10-11
# 19                ENGIE                   Paris Stock Exchange  2018-10-11
# 12                DANONE                  Paris Stock Exchange  2018-10-11
# 7   HERMES INTERNATIONAL                  Paris Stock Exchange  2018-10-11
# 9                  VINCI                  Paris Stock Exchange  2018-10-11
# 15    SCHNEIDER ELECTRIC                  Paris Stock Exchange  2018-10-11
# 32             CARREFOUR                  Paris Stock Exchange  2018-10-11
# 24               RENAULT                  Paris Stock Exchange  2018-10-11
# 28               LEGRAND                  Paris Stock Exchange  2018-10-11
# 16       CREDIT AGRICOLE                  Paris Stock Exchange  2018-10-11
# 20      SOCIETE GENERALE                  Paris Stock Exchange  2018-10-11
# 4                AIRBUS                   Paris Stock Exchange  2018-10-11
# 29              BOUYGUES                  Paris Stock Exchange  2018-10-11
# 25          SAINT-GOBAIN                  Paris Stock Exchange  2018-10-11
# 33            TECHNIPFMC               New York Stock Exchange  2018-10-11
# 13      ESSILORLUXOTTICA                  Paris Stock Exchange  2018-10-11
# 8                KERING                   Paris Stock Exchange  2018-10-11
# 11                SAFRAN                  Paris Stock Exchange  2018-10-11
# 10           AIR LIQUIDE                  Paris Stock Exchange  2018-10-11
# 37                 VALEO                  Paris Stock Exchange  2018-10-11
# 35                  ATOS  NASDAQ Stock Exchange Capital Market  2018-10-11
# 0                  TOTAL                  Lagos Stock Exchange  2018-10-11
#
#      Price Currency  Change  Shared_owned Company_divident_yield  \
# 34   51.04      EUR  0.0000         46.08                   3.81
# 14   13.85      EUR  0.0000         45.16                   5.15
# 2    191.3      EUR  0.0000         14.68                   1.78
# 30    17.1      CHF  0.0000         30.05                   1.02
# 5    51.47      EUR  0.0000         42.04                    5.9
# 6    23.25      NOK  0.0000         28.43                      ?
# 27  104.55      EUR  0.0000         45.38                   1.56
# 26   99.26      EUR  0.0000         39.16                   3.43
# 23   163.4      EUR  0.0000         38.23                   6.62
# 22   24.76      EUR  0.0000         25.91                   0.33
# 1   265.05      EUR  0.0000         20.63                   1.82
# 18     114      EUR  0.0000         21.21                   0.49
# 36   17.27      EUR  0.0000         53.10                   4.06
# 3        ?        ? -0.0021         41.28                   1.67
# 17   131.9      EUR -0.0023         62.24                   1.54
# 21   21.41      EUR -0.0042         46.62                   1.89
# 31   86.14      EUR -0.0083         22.80                   3.17
# 19   12.06      EUR -0.0090         31.32                   5.94
# 12   64.67      EUR -0.0101         50.60                    2.9
# 7      500      EUR -0.0107         10.14                   0.78
# 9    78.02      EUR -0.0112         34.00                    2.7
# 15      62      EUR -0.0112         48.18                   3.36
# 32   15.44      EUR -0.0122         23.61                   4.12
# 24   70.18      EUR -0.0132         29.42                   4.94
# 28   57.68      EUR -0.0133         41.33                   2.09
# 16   12.33      EUR -0.0142         12.29                   5.09
# 20    36.1      EUR -0.0151         49.37                   6.06
# 4    97.47      EUR -0.0154         43.60                   1.66
# 29   35.66      EUR -0.0155         33.49                   4.65
# 25   33.48      EUR -0.0157         39.17                   3.69
